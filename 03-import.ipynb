# %%
import datalook
# Out:
#   File "C:\Users\Cris\desktop\sc-python\datalook.py", line 53
#     if__name__== "__main__":
#                            ^
# SyntaxError: invalid syntax

# %%
import pdatalook
# Out:
# Running C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py
# -f
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5946cf444e3b> in <module>()
# ----> 1 import pdatalook
#
# C:\Users\Cris\desktop\sc-python\pdatalook.py in <module>()
#      54
#      55 print (sys.argv[1])
# ---> 56 analyse (sys.argv[1], outfile=sys.argv[2])
#      57 detect_problems (sys.argv[1])
#
# C:\Users\Cris\desktop\sc-python\pdatalook.py in analyse(filename, outfile)
#       8
#       9 def analyse (filename, outfile=None):
# ---> 10     data = numpy.loadtxt(fname=filename, delimiter=',')
#      11
#      12      #Create a wide figure to hold subplots
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     803                 fh = iter(open(fname, 'U'))
# ...

# %%
help(datalook.analyse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0b6359055620> in <module>()
# ----> 1 help(datalook.analyse)
#
# NameError: name 'datalook' is not defined

# %%
help(pdatalook.analyse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0d7403bcc87d> in <module>()
# ----> 1 help(pdatalook.analyse)
#
# NameError: name 'pdatalook' is not defined

# %%
import pdatalook
# Out:
#   File "C:\Users\Cris\desktop\sc-python\pdatalook.py", line 53
#     if__name__== "__main__":
#                            ^
# SyntaxError: invalid syntax

# %%
import datalook

# %%
help(datalook.analyse)
# Out:
# Help on function analyse in module datalook:
#
# analyse(filename, outfile=None)

# %%
datalook.analyse("data/weather-01.csv")
